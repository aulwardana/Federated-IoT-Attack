# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
from keras.metrics import Recall, Precision
import time
import psutil
import sys
import threading
import json
from web3 import Web3, HTTPProvider
# Out:
# 2024-02-09 15:27:22.173030: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-09 15:27:22.237958: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-09 15:27:22.239269: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-09 15:27:23.419625: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
blockchain_address = 'http://127.0.0.1:8545'
web3 = Web3(HTTPProvider(blockchain_address))
web3.is_connected()
# Out:
# True

# %%
web3.eth.defaultAccount = web3.eth.accounts[0]
print(web3.eth.accounts[0])
# Out:
# 0x8348eC8A6293180f7c56baC764A190601c5cF5DD

# %%
compiled_contract_path_edge = '/home/administrator/docker-eth/build/contracts/ids.json'
compiled_contract_path_fog = '/home/administrator/docker-eth/build/contracts/ids.json'
compiled_contract_path_cloud = '/home/administrator/docker-eth/build/contracts/ids.json'

def compile_contract (compiled_contract_path):
    with open(compiled_contract_path) as file:
        contract_json = json.load(file) 
        contract_abi = contract_json['abi']
    
    return contract_abi
        
abi_edge = compile_contract(compiled_contract_path_edge)
abi_fog = compile_contract(compiled_contract_path_fog)
abi_cloud = compile_contract(compiled_contract_path_cloud)

# %%
deployed_contract_address_edge = '0x9B211180B1E9189305897AfD2f1f82bf9815FCf5'
deployed_contract_address_fog = '0x9B211180B1E9189305897AfD2f1f82bf9815FCf5'
deployed_contract_address_cloud = '0x9B211180B1E9189305897AfD2f1f82bf9815FCf5'

contract_edge = web3.eth.contract(address = deployed_contract_address_edge, abi = abi_edge)
contract_fog = web3.eth.contract(address = deployed_contract_address_fog, abi = abi_fog)
contract_cloud = web3.eth.contract(address = deployed_contract_address_cloud, abi = abi_cloud)

# %%
chunksize = 1000

# %%
list_of_dataframes = []

for dfp in pd.read_csv('/home/administrator/dataset/CIC-IoT-2023/test_CICIoT2023.csv', chunksize=chunksize):
    list_of_dataframes.append(dfp)

df = pd.concat(list_of_dataframes)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14005974 entries, 0 to 14005973
# Data columns (total 47 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   flow_duration    float64
#  1   Header_Length    float64
#  2   Protocol Type    float64
#  3   Duration         float64
#  4   Rate             float64
#  5   Srate            float64
#  6   Drate            float64
#  7   fin_flag_number  float64
#  8   syn_flag_number  float64
#  9   rst_flag_number  float64
#  10  psh_flag_number  float64
#  11  ack_flag_number  float64
#  12  ece_flag_number  float64
#  13  cwr_flag_number  float64
#  14  ack_count        float64
#  15  syn_count        float64
#  16  fin_count        float64
#  17  urg_count        float64
#  18  rst_count        float64
#  19  HTTP             float64
#  20  HTTPS            float64
#  21  DNS              float64
#  22  Telnet           float64
#  23  SMTP             float64
#  24  SSH              float64
#  25  IRC              float64
#  26  TCP              float64
#  27  UDP              float64
#  28  DHCP             float64
#  29  ARP              float64
#  30  ICMP             float64
#  31  IPv              float64
#  32  LLC              float64
#  33  Tot sum          float64
#  34  Min              float64
#  35  Max              float64
#  36  AVG              float64
#  37  Std              float64
#  38  Tot size         float64
#  39  IAT              float64
#  40  Number           float64
#  41  Magnitue         float64
#  42  Radius           float64
#  43  Covariance       float64
#  44  Variance         float64
#  45  Weight           float64
#  46  label            object
# dtypes: float64(46), object(1)
# memory usage: 4.9+ GB

# %%
df['label'].value_counts()
# Out:
# label
# DDoS          10197039
# DoS            2426635
# Mirai           790305
# Benign          328597
# Spoofing        145999
# Recon           105957
# Web               7462
# BruteForce        3980
# Name: count, dtype: int64

# %%
trf_type = df.loc[:, "label"].map(lambda lbl: "0" if lbl == "Benign" else "1")
trf_type.name = "traffic type"
df.loc[:, trf_type.name] = trf_type

# %%
df['traffic type'].value_counts()
# Out:
# traffic type
# 1    13677377
# 0      328597
# Name: count, dtype: int64

# %%
df['traffic type'] = df['traffic type'].astype(int)

# %%
X_df = df.drop(columns=['label', 'traffic type'])
y_df = df['traffic type']

# %%
# Split into training and validation sets
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, test_size=0.2, random_state=100)

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
def load_CICIoT2023_data(client_id):
    
    # Create non-IID splits based on client_id
    np.random.seed(client_id)
    indices = np.arange(len(X_train))
    np.random.shuffle(indices)

    # Choose a fraction of the data for this client
    fraction = 0.04
    client_data_size = int(fraction * len(X_train))
    client_indices = indices[:client_data_size]

    X_client = X_train[client_indices]
    y_client = y_train.iloc[client_indices]

    return X_client, y_client, X_test, y_test

# %%
# Define a simple neural network for binary classification
def create_classification_model(input_shape):
    model = keras.Sequential([
        layers.Dense(21, activation='relu', input_shape=(input_shape,)),
        layers.Dense(13, activation='relu'),
        layers.Dense(7, activation='relu'),
        layers.Dense(5, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy', Recall(), Precision()])
    return model

# %%
# Function to monitor resources
def monitor_resources(cpu_percent_list, memory_usage_list, stop_event=None):
    while not stop_event.is_set():
        cpu_percent = psutil.cpu_percent(interval=1)
        memory_info = psutil.virtual_memory()

        cpu_percent_list.append(cpu_percent)
        memory_usage_list.append(memory_info.used / (1024 ** 3))  # Convert to GB

# %%
# Function to save weight into ethereum blockchain
def save_transaction_edge(weight_edge):
    tx_hash_edge = contract_edge.functions.sendHash(weight_edge).transact({'from': web3.eth.accounts[0]})
    tx_receipt_edge = web3.eth.wait_for_transaction_receipt(tx_hash_edge)
    print('tx_hash_edge: {}'.format(tx_hash_edge.hex()))
    print(tx_receipt_edge)

def save_transaction_fog(weight_fog):
    tx_hash_fog = contract_fog.functions.sendHash(weight_fog).transact({'from': web3.eth.accounts[0]})
    tx_receipt_fog = web3.eth.wait_for_transaction_receipt(tx_hash_fog)
    print('tx_hash_fog: {}'.format(tx_hash_fog.hex()))
    print(tx_receipt_fog)
    
def save_transaction_cloud(weight_cloud):
    tx_hash_cloud = contract_cloud.functions.sendHash(weight_cloud).transact({'from': web3.eth.accounts[0]})
    tx_receipt_cloud = web3.eth.wait_for_transaction_receipt(tx_hash_cloud)
    print('tx_hash_cloud: {}'.format(tx_hash_cloud.hex()))
    print(tx_receipt_cloud)
    
#Function to recall weight
def recall_transaction_edge(num):
    current_block_edge = w3.eth.blockNumber
    edge_models = []
    for i in range(num):
        blocks_before_edge = current_block_edge - i
        contract_state_edge = contract_edge.atBlock(blocks_before_edge)
        output_edge = contract_state_edge.functions.getHash().call()
        edge_models.append(output_edge)
    return edge_models

def recall_transaction_fog(num):
    current_block_fog = w3.eth.blockNumber
    fog_models = []
    for i in range(num):
        blocks_before_fog = current_block_fog - i
        contract_state_fog = contract_fog.atBlock(blocks_before_fog)
        output_fog = contract_state_fog.functions.getHash().call()
        fog_models.append(output_fog)
    return fog_models

def recall_transaction_cloud(num):
    current_block_cloud = w3.eth.blockNumber
    cloud_models = []
    for i in range(num):
        blocks_before_cloud = current_block_cloud - i
        contract_state_cloud = contract_cloud.atBlock(blocks_before_cloud)
        output_cloud = contract_state_cloud.functions.getHash().call()
        cloud_models.append(output_cloud)
    return cloud_models

# %%
input_shape = X_train.shape[1]

# Initialize global classification model
cloud_model = create_classification_model(input_shape=input_shape)

# %%
# Number of federated learning rounds
num_rounds = 5
num_fog = 5
num_edge = 5

cloud_models = []

# Federated learning simulation
for round in range(num_rounds):

    # Fog layer with 5 devices
    for fog_device_id in range(num_fog):  # Assuming 5 devices
        
        # Create a copy of the cloud model for each fog device
        fog_model = keras.models.clone_model(cloud_model)
        fog_model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy', Recall(), Precision()])
        
        # Assuming each fog device manages 5 edge devices
        for edge_device_id in range(num_edge):
            
             # Create a copy of the fog model for each edge device
            edge_model = keras.models.clone_model(fog_model)
            edge_model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy', Recall(), Precision()])
            
            # Load non-IID data for each client
            X_local, y_local, X_test_local, y_test_local = load_CICIoT2023_data(client_id=edge_device_id)

            # Measure resource utilization
            # Create a threading.Event to signal the monitoring thread to stop
            stop_monitoring = threading.Event()

            # Create lists to store CPU and memory utilization values
            cpu_percent_list = []
            memory_usage_list = []

            # Start monitoring in a separate thread
            monitor_thread = threading.Thread(target=monitor_resources, args=(cpu_percent_list, memory_usage_list, stop_monitoring))
            monitor_thread.start()

            # Start time of training
            start_train = time.time()

            # Perform local training using the client's data
            edge_model.fit(X_local, y_local, epochs=10, verbose=0)

            # End time of training
            end_train = time.time()

            # Signal the monitoring thread to stop
            stop_monitoring.set()

            # Wait for the monitoring thread to finish
            monitor_thread.join()

            # Calculte training time
            train_time = end_train - start_train
            
            # Calculate the average CPU and memory utilization
            average_cpu_percent = sum(cpu_percent_list) / len(cpu_percent_list)
            average_memory_usage = sum(memory_usage_list) / len(memory_usage_list)

            # Measure edge model size in bytes
            current_model_size_edge_bytes = sys.getsizeof(edge_model)

            # Convert to megabytes
            current_model_size_edge_mb = current_model_size_edge_bytes / 1024  # 1 MB = 1024 KB

            # Evaluate edge model on the testing set
            loss_egde, accuracy_edge, recall_edge, precision_edge = edge_model.evaluate(X_test_local, y_test_local, verbose=0)

            start_save_time_edge = time.time()
            
            # Append the local model weights to edge_models
            save_transaction_edge(edge_model.get_weights())
            
            end_save_time_edge = time.time()
            
            latency_dlt_edge = end_save_time_edge - start_save_time_edge
            
            print('================================================================================================================')
            print(f"Round {round + 1}, Edge Device {edge_device_id + 1}: Edge Model - Loss: {loss_egde}, Accuracy: {accuracy_edge}, Recall: {recall_edge}, Precision: {precision_edge}")
            print(f"Training Time: {train_time} seconds, Model Size: {current_model_size_edge_mb} KB, DLT Latency - Write data to block: {latency_dlt_edge} seconds")
            print(f"Average CPU Percent: {average_cpu_percent:.2f}%, Average Memory Usage: {average_memory_usage:.2f} GB")
        
        start_recall_time_edge = time.time()
        
        edge_models = recall_transaction_edge(num_edge)
        
        end_recall_time_edge = time.time()
        
        latency_dlt_rec_edge = end_recall_time_edge - start_recall_time_edge
        
        # Coordinate-wise mean aggregation for edge layer in fog device
        global_edge_weights = []
        for layer_edge_weights in zip(*edge_models):
            mean_edge_weights = np.mean(layer_edge_weights, axis=0)
            global_edge_weights.append(mean_edge_weights)

        # Update fog model with aggregated weights for the edge layer
        fog_model.set_weights(global_edge_weights)
        
        # Measure fog model size in bytes
        current_model_size_fog_bytes = sys.getsizeof(fog_model)

        # Convert to megabytes
        current_model_size_fog_mb = current_model_size_fog_bytes / 1024  # 1 MB = 1024 KB
        
        # Evaluate edge model on the testing set
        loss_fog, accuracy_fog, recall_fog, precision_fog = fog_model.evaluate(X_test, y_test, verbose=0)
        
        start_save_time_fog = time.time()
        
        # Append the local model weights to fog_models
        save_transaction_fog(fog_model.get_weights())
        
        end_save_time_fog = time.time()
            
        latency_dlt_fog = end_save_time_fog - start_save_time_fog
                       
        print('================================================================================================================')
        print(f"Round {round + 1}, Fog Device {fog_device_id + 1}: Fog Model - Loss: {loss_fog}, Accuracy: {accuracy_fog}, Recall: {recall_fog}, Precision: {precision_fog}")
        print(f"Global Model Size - {current_model_size_fog_mb} KB")
        print(f"DLT Latency - Write data to block: {latency_dlt_fog} seconds, Read data from block: {latency_dlt_rec_edge} seconds")
    
    start_recall_time_fog = time.time()
    
    fog_models = recall_transaction_fog(num_fog)
    
    end_recall_time_fog = time.time()
        
    latency_dlt_rec_fog = end_recall_time_fog - start_recall_time_fog
    
    # Coordinate-wise mean aggregation for fog layer
    global_fog_weights = []
    for layer_fog_weights in zip(*fog_models):
        mean_fog_weights = np.mean(layer_fog_weights, axis=0)
        global_fog_weights.append(mean_fog_weights)

    # Update global model with aggregated weights for the fog layer
    cloud_model.set_weights(global_fog_weights)
    
    # Measure global model size in bytes
    current_model_size_global_bytes = sys.getsizeof(cloud_model)

    # Convert to megabytes
    current_model_size_global_mb = current_model_size_global_bytes / 1024  # 1 MB = 1024 KB

    # Evaluate global model on the validation set
    score_global = cloud_model.evaluate(X_test, y_test, verbose=0)
    
    start_save_time_cloud = time.time()
    
    # Append the local model weights to cloud_models
    save_transaction_cloud(cloud_model.get_weights())
    
    end_save_time_cloud = time.time()
            
    latency_dlt_cloud = end_save_time_cloud - start_save_time_cloud
    
    print('===================================================================================================================')
    print(f"Round {round + 1}: Global Model - Loss: {score_global[0]}, Accuracy: {score_global[1]}, Recall: {score_global[2]}, Precision: {score_global[3]}")
    print(f"Global Model Size - {current_model_size_global_mb} KB")
    print(f"DLT Latency - Write data to block: {latency_dlt_cloud} seconds, Read data from block: {latency_dlt_rec_fog} seconds")

start_recall_time_cloud = time.time()
    
cloud_models = recall_transaction_cloud(num_rounds)  

end_recall_time_cloud = time.time()
            
latency_dlt_rec_cloud = end_recall_time_cloud - start_recall_time_cloud

# Coordinate-wise mean aggregation for cloud layer
global_cloud_weights = []
for layer_cloud_weights in zip(*cloud_models):
    mean_cloud_weights = np.mean(layer_cloud_weights, axis=0)
    global_cloud_weights.append(mean_cloud_weights)
    
# Final global classification model
final_global_model = create_classification_model(input_shape=input_shape)

# Update final model with aggregated weights for the cloud layer
final_global_model.set_weights(global_cloud_weights)

# Measure final model size in bytes
current_model_size_final_bytes = sys.getsizeof(final_global_mode)

# Convert to megabytes
current_model_size_final_mb = current_model_size_final_bytes / 1024  # 1 MB = 1024 KB

# Evaluate final model on the validation set
score_final = final_global_model.evaluate(X_test, y_test, verbose=0)

print('===================================================================================================================')
print(f"Final Model - Loss: {score_final[0]}, Accuracy: {score_final[1]}, Recall: {score_final[2]}, Precision: {score_final[3]}")
print(f"Final Model Size - {current_model_size_final_mb} KB, DLT Latency - Read data from block: {latency_dlt_rec_fog} seconds")
# Out:
# ================================================================================================================
# Round 1, Edge Device 1: Edge Model - Loss: 0.0063963886350393295, Accuracy: 0.9908539056777954, Recall: 0.993236243724823, Precision: 0.9973869919776917
# Training Time: 149.38945198059082 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.86%, Average Memory Usage: 26.79 GB
# ================================================================================================================
# Round 1, Edge Device 2: Edge Model - Loss: 0.007170390337705612, Accuracy: 0.9903984069824219, Recall: 0.9927833080291748, Precision: 0.9973722696304321
# Training Time: 159.3181664943695 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.65%, Average Memory Usage: 27.40 GB
# ================================================================================================================
# Round 1, Edge Device 3: Edge Model - Loss: 0.006185179576277733, Accuracy: 0.9910959601402283, Recall: 0.99381023645401, Precision: 0.9970622062683105
# Training Time: 159.62023758888245 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.68%, Average Memory Usage: 28.07 GB
# ================================================================================================================
# Round 1, Edge Device 4: Edge Model - Loss: 0.015226216055452824, Accuracy: 0.9832992553710938, Recall: 0.9964474439620972, Precision: 0.9865847229957581
# Training Time: 153.32422804832458 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.83%, Average Memory Usage: 23.52 GB
# ================================================================================================================
# Round 1, Edge Device 5: Edge Model - Loss: 0.0069371419958770275, Accuracy: 0.9904412031173706, Recall: 0.9935389757156372, Precision: 0.9966621398925781
# Training Time: 158.83258414268494 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.73%, Average Memory Usage: 24.04 GB
# ================================================================================================================
# Round 1, Fog Device 1: Fog Model - Loss: 0.08174498379230499, Accuracy: 0.9767463803291321, Recall: 0.9996142983436584, Precision: 0.9771009683609009
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 1, Edge Device 1: Edge Model - Loss: 0.00652081985026598, Accuracy: 0.9907325506210327, Recall: 0.9945617914199829, Precision: 0.9959424138069153
# Training Time: 153.52500915527344 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.86%, Average Memory Usage: 25.23 GB
# ================================================================================================================
# Round 1, Edge Device 2: Edge Model - Loss: 0.006570613943040371, Accuracy: 0.9904433488845825, Recall: 0.9938825964927673, Precision: 0.9963221549987793
# Training Time: 151.25993657112122 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.87%, Average Memory Usage: 25.88 GB
# ================================================================================================================
# Round 1, Edge Device 3: Edge Model - Loss: 0.007659336552023888, Accuracy: 0.989726185798645, Recall: 0.9931371808052063, Precision: 0.9963303804397583
# Training Time: 153.08951687812805 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.88%, Average Memory Usage: 26.54 GB
# ================================================================================================================
# Round 1, Edge Device 4: Edge Model - Loss: 0.006348063703626394, Accuracy: 0.9910391569137573, Recall: 0.9946122765541077, Precision: 0.9962055683135986
# Training Time: 152.21928524971008 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.83%, Average Memory Usage: 27.22 GB
# ================================================================================================================
# Round 1, Edge Device 5: Edge Model - Loss: 0.006684622727334499, Accuracy: 0.9903841018676758, Recall: 0.9927803874015808, Precision: 0.9973605275154114
# Training Time: 146.44201278686523 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.86%, Average Memory Usage: 27.88 GB
# ================================================================================================================
# Round 1, Fog Device 2: Fog Model - Loss: 0.17264652252197266, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 1, Edge Device 1: Edge Model - Loss: 0.005915520712733269, Accuracy: 0.9915428757667542, Recall: 0.9939191341400146, Precision: 0.9974114894866943
# Training Time: 151.91170287132263 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.84%, Average Memory Usage: 29.08 GB
# ================================================================================================================
# Round 1, Edge Device 2: Edge Model - Loss: 0.006756880320608616, Accuracy: 0.991015613079071, Recall: 0.9927383661270142, Precision: 0.9980510473251343
# Training Time: 155.31241035461426 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.78%, Average Memory Usage: 29.72 GB
# ================================================================================================================
# Round 1, Edge Device 3: Edge Model - Loss: 0.006853743921965361, Accuracy: 0.9902934432029724, Recall: 0.99381422996521, Precision: 0.9962368607521057
# Training Time: 155.6542992591858 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.73%, Average Memory Usage: 30.38 GB
# ================================================================================================================
# Round 1, Edge Device 4: Edge Model - Loss: 0.006496130954474211, Accuracy: 0.9911808967590332, Recall: 0.9942649602890015, Precision: 0.9966959953308105
# Training Time: 155.3027172088623 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.79%, Average Memory Usage: 31.04 GB
# ================================================================================================================
# Round 1, Edge Device 5: Edge Model - Loss: 0.006097162142395973, Accuracy: 0.9912408590316772, Recall: 0.9941626191139221, Precision: 0.9968593120574951
# Training Time: 146.8875641822815 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 5.00%, Average Memory Usage: 31.71 GB
# ================================================================================================================
# Round 1, Fog Device 3: Fog Model - Loss: 0.16061128675937653, Accuracy: 0.9765039682388306, Recall: 0.999965250492096, Precision: 0.9765370488166809
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 1, Edge Device 1: Edge Model - Loss: 0.0064027076587080956, Accuracy: 0.990635097026825, Recall: 0.9928187727928162, Precision: 0.9975797533988953
# Training Time: 163.58847522735596 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.58%, Average Memory Usage: 25.25 GB
# ================================================================================================================
# Round 1, Edge Device 2: Edge Model - Loss: 0.006491976790130138, Accuracy: 0.9907689690589905, Recall: 0.9936423897743225, Precision: 0.9968945980072021
# Training Time: 156.2440164089203 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.77%, Average Memory Usage: 25.90 GB
# ================================================================================================================
# Round 1, Edge Device 3: Edge Model - Loss: 0.006956473924219608, Accuracy: 0.9898393154144287, Recall: 0.9944689869880676, Precision: 0.995123028755188
# Training Time: 150.70016622543335 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.92%, Average Memory Usage: 26.51 GB
# ================================================================================================================
# Round 1, Edge Device 4: Edge Model - Loss: 0.006254449021071196, Accuracy: 0.991254448890686, Recall: 0.9942010045051575, Precision: 0.996834933757782
# Training Time: 159.16608834266663 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.71%, Average Memory Usage: 27.14 GB
# ================================================================================================================
# Round 1, Edge Device 5: Edge Model - Loss: 0.006195690017193556, Accuracy: 0.9912601709365845, Recall: 0.9946451783180237, Precision: 0.9963986873626709
# Training Time: 149.1028425693512 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 5.02%, Average Memory Usage: 27.76 GB
# ================================================================================================================
# Round 1, Fog Device 4: Fog Model - Loss: 0.1425672173500061, Accuracy: 0.9765368103981018, Recall: 0.999998927116394, Precision: 0.976537823677063
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 1, Edge Device 1: Edge Model - Loss: 0.006675678305327892, Accuracy: 0.99039626121521, Recall: 0.994596540927887, Precision: 0.9955646395683289
# Training Time: 152.18476939201355 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.84%, Average Memory Usage: 28.91 GB
# ================================================================================================================
# Round 1, Edge Device 2: Edge Model - Loss: 0.006030294578522444, Accuracy: 0.9913918972015381, Recall: 0.9941673874855042, Precision: 0.9970091581344604
# Training Time: 150.21265745162964 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.91%, Average Memory Usage: 29.55 GB
# ================================================================================================================
# Round 1, Edge Device 3: Edge Model - Loss: 0.013951985165476799, Accuracy: 0.9836926460266113, Recall: 0.997025728225708, Precision: 0.9864211082458496
# Training Time: 161.16407537460327 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.68%, Average Memory Usage: 30.10 GB
# ================================================================================================================
# Round 1, Edge Device 4: Edge Model - Loss: 0.006312335841357708, Accuracy: 0.9909706115722656, Recall: 0.9945929050445557, Precision: 0.99615478515625
# Training Time: 153.79833674430847 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.78%, Average Memory Usage: 30.73 GB
# ================================================================================================================
# Round 1, Edge Device 5: Edge Model - Loss: 0.00622734148055315, Accuracy: 0.9911416172981262, Recall: 0.9939751029014587, Precision: 0.9969446063041687
# Training Time: 160.76747751235962 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.67%, Average Memory Usage: 31.38 GB
# ================================================================================================================
# Round 1, Fog Device 5: Fog Model - Loss: 0.14072170853614807, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ===================================================================================================================
# Round 1: Global Model - Loss: 0.14768625795841217, Accuracy: 0.9765346646308899, Recall: 0.9999967217445374, Precision: 0.976537823677063
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 2, Edge Device 1: Edge Model - Loss: 0.0063215321861207485, Accuracy: 0.9907236099243164, Recall: 0.9946155548095703, Precision: 0.9958799481391907
# Training Time: 156.1115481853485 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.83%, Average Memory Usage: 33.14 GB
# ================================================================================================================
# Round 2, Edge Device 2: Edge Model - Loss: 0.006451673340052366, Accuracy: 0.9907325506210327, Recall: 0.994059145450592, Precision: 0.9964421987533569
# Training Time: 157.85784006118774 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.67%, Average Memory Usage: 25.73 GB
# ================================================================================================================
# Round 2, Edge Device 3: Edge Model - Loss: 0.015825143083930016, Accuracy: 0.9819884300231934, Recall: 0.9952614903450012, Precision: 0.9864159822463989
# Training Time: 153.37915205955505 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.84%, Average Memory Usage: 26.29 GB
# ================================================================================================================
# Round 2, Edge Device 4: Edge Model - Loss: 0.00711184972897172, Accuracy: 0.9905229806900024, Recall: 0.9944196343421936, Precision: 0.9958696365356445
# Training Time: 162.61097311973572 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.61%, Average Memory Usage: 26.92 GB
# ================================================================================================================
# Round 2, Edge Device 5: Edge Model - Loss: 0.01552495639771223, Accuracy: 0.9828751683235168, Recall: 0.9959747195243835, Precision: 0.9866159558296204
# Training Time: 149.77355670928955 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.89%, Average Memory Usage: 27.54 GB
# ================================================================================================================
# Round 2, Fog Device 1: Fog Model - Loss: 0.09541548043489456, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 2, Edge Device 1: Edge Model - Loss: 0.0064149838872253895, Accuracy: 0.9909628033638, Recall: 0.9933506846427917, Precision: 0.9973843693733215
# Training Time: 162.19109988212585 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.64%, Average Memory Usage: 28.68 GB
# ================================================================================================================
# Round 2, Edge Device 2: Edge Model - Loss: 0.006718538701534271, Accuracy: 0.9904658794403076, Recall: 0.9935765862464905, Precision: 0.9966498613357544
# Training Time: 151.3412365913391 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.88%, Average Memory Usage: 29.31 GB
# ================================================================================================================
# Round 2, Edge Device 3: Edge Model - Loss: 0.0062039936892688274, Accuracy: 0.9911594986915588, Recall: 0.9933367967605591, Precision: 0.9976000189781189
# Training Time: 154.86582612991333 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.80%, Average Memory Usage: 29.95 GB
# ================================================================================================================
# Round 2, Edge Device 4: Edge Model - Loss: 0.006838195025920868, Accuracy: 0.9908760190010071, Recall: 0.99247807264328, Precision: 0.9981682896614075
# Training Time: 154.53117513656616 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.74%, Average Memory Usage: 30.53 GB
# ================================================================================================================
# Round 2, Edge Device 5: Edge Model - Loss: 0.006637990940362215, Accuracy: 0.9904919266700745, Recall: 0.9930845499038696, Precision: 0.9971672892570496
# Training Time: 152.49641585350037 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.89%, Average Memory Usage: 31.16 GB
# ================================================================================================================
# Round 2, Fog Device 2: Fog Model - Loss: 0.1438819020986557, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 2, Edge Device 1: Edge Model - Loss: 0.006112207192927599, Accuracy: 0.9912822842597961, Recall: 0.993893563747406, Precision: 0.9971699714660645
# Training Time: 153.7792727947235 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.78%, Average Memory Usage: 32.35 GB
# ================================================================================================================
# Round 2, Edge Device 2: Edge Model - Loss: 0.007318779360502958, Accuracy: 0.9901338815689087, Recall: 0.9930644631385803, Precision: 0.9968203902244568
# Training Time: 146.78275275230408 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.80%, Average Memory Usage: 33.00 GB
# ================================================================================================================
# Round 2, Edge Device 3: Edge Model - Loss: 0.007465554866939783, Accuracy: 0.9894855618476868, Recall: 0.9928293824195862, Precision: 0.9963906407356262
# Training Time: 158.9526162147522 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.63%, Average Memory Usage: 33.63 GB
# ================================================================================================================
# Round 2, Edge Device 4: Edge Model - Loss: 0.006403271108865738, Accuracy: 0.9908357262611389, Recall: 0.9933594465255737, Precision: 0.9972453117370605
# Training Time: 154.56469750404358 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.86%, Average Memory Usage: 26.62 GB
# ================================================================================================================
# Round 2, Edge Device 5: Edge Model - Loss: 0.006179974880069494, Accuracy: 0.9912990927696228, Recall: 0.9928542375564575, Precision: 0.9982262253761292
# Training Time: 149.16515064239502 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.91%, Average Memory Usage: 27.17 GB
# ================================================================================================================
# Round 2, Fog Device 3: Fog Model - Loss: 0.13328440487384796, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 2, Edge Device 1: Edge Model - Loss: 0.006226236466318369, Accuracy: 0.9911119937896729, Recall: 0.99395751953125, Precision: 0.996931791305542
# Training Time: 165.45908546447754 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.53%, Average Memory Usage: 28.32 GB
# ================================================================================================================
# Round 2, Edge Device 2: Edge Model - Loss: 0.0062288385815918446, Accuracy: 0.991009533405304, Recall: 0.9933766722679138, Precision: 0.9974064230918884
# Training Time: 154.49283456802368 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.81%, Average Memory Usage: 28.95 GB
# ================================================================================================================
# Round 2, Edge Device 3: Edge Model - Loss: 0.007034220267087221, Accuracy: 0.9904458522796631, Recall: 0.993099570274353, Precision: 0.9971051216125488
# Training Time: 157.19882822036743 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.80%, Average Memory Usage: 29.58 GB
# ================================================================================================================
# Round 2, Edge Device 4: Edge Model - Loss: 0.02308247983455658, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Training Time: 156.36079120635986 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.77%, Average Memory Usage: 30.21 GB
# ================================================================================================================
# Round 2, Edge Device 5: Edge Model - Loss: 0.006411031819880009, Accuracy: 0.9908813834190369, Recall: 0.9940419793128967, Precision: 0.9966115951538086
# Training Time: 156.10124254226685 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.73%, Average Memory Usage: 30.85 GB
# ================================================================================================================
# Round 2, Fog Device 4: Fog Model - Loss: 0.1270570605993271, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 2, Edge Device 1: Edge Model - Loss: 0.006165566388517618, Accuracy: 0.9913687109947205, Recall: 0.9952545762062073, Precision: 0.9959040880203247
# Training Time: 152.27062940597534 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.92%, Average Memory Usage: 31.97 GB
# ================================================================================================================
# Round 2, Edge Device 2: Edge Model - Loss: 0.00647501228377223, Accuracy: 0.9906597137451172, Recall: 0.9944397211074829, Precision: 0.9959893226623535
# Training Time: 162.2671616077423 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.70%, Average Memory Usage: 32.62 GB
# ================================================================================================================
# Round 2, Edge Device 3: Edge Model - Loss: 0.006090567447245121, Accuracy: 0.991433322429657, Recall: 0.9944130182266235, Precision: 0.996806800365448
# Training Time: 151.0941469669342 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.88%, Average Memory Usage: 33.21 GB
# ================================================================================================================
# Round 2, Edge Device 4: Edge Model - Loss: 0.005901259370148182, Accuracy: 0.991531491279602, Recall: 0.9936003684997559, Precision: 0.9977182149887085
# Training Time: 148.86009097099304 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.89%, Average Memory Usage: 33.87 GB
# ================================================================================================================
# Round 2, Edge Device 5: Edge Model - Loss: 0.006427559070289135, Accuracy: 0.9907225370407104, Recall: 0.9951339364051819, Precision: 0.9953646063804626
# Training Time: 158.65156602859497 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.69%, Average Memory Usage: 34.52 GB
# ================================================================================================================
# Round 2, Fog Device 5: Fog Model - Loss: 0.1376376897096634, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ===================================================================================================================
# Round 2: Global Model - Loss: 0.15327732264995575, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 3, Edge Device 1: Edge Model - Loss: 0.006479667034000158, Accuracy: 0.9905825853347778, Recall: 0.9927807450294495, Precision: 0.997563898563385
# Training Time: 150.58393383026123 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.81%, Average Memory Usage: 28.12 GB
# ================================================================================================================
# Round 3, Edge Device 2: Edge Model - Loss: 0.006394883152097464, Accuracy: 0.9908585548400879, Recall: 0.9941074252128601, Precision: 0.9965230822563171
# Training Time: 149.78019762039185 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.79%, Average Memory Usage: 28.75 GB
# ================================================================================================================
# Round 3, Edge Device 3: Edge Model - Loss: 0.007730596698820591, Accuracy: 0.9890468120574951, Recall: 0.9905117154121399, Precision: 0.9982584714889526
# Training Time: 148.31029772758484 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 5.01%, Average Memory Usage: 29.38 GB
# ================================================================================================================
# Round 3, Edge Device 4: Edge Model - Loss: 0.0151245491579175, Accuracy: 0.9832274913787842, Recall: 0.9957930445671082, Precision: 0.9871441125869751
# Training Time: 154.3435139656067 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.79%, Average Memory Usage: 30.00 GB
# ================================================================================================================
# Round 3, Edge Device 5: Edge Model - Loss: 0.006936265621334314, Accuracy: 0.9905732870101929, Recall: 0.993315577507019, Precision: 0.9970201253890991
# Training Time: 144.3382692337036 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.95%, Average Memory Usage: 30.61 GB
# ================================================================================================================
# Round 3, Fog Device 1: Fog Model - Loss: 0.14148777723312378, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 3, Edge Device 1: Edge Model - Loss: 0.006556338164955378, Accuracy: 0.9907968044281006, Recall: 0.9956709742546082, Precision: 0.9949086308479309
# Training Time: 149.94825625419617 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.90%, Average Memory Usage: 31.75 GB
# ================================================================================================================
# Round 3, Edge Device 2: Edge Model - Loss: 0.006543219089508057, Accuracy: 0.9911030530929565, Recall: 0.9934768080711365, Precision: 0.9974023103713989
# Training Time: 156.04537630081177 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.75%, Average Memory Usage: 32.38 GB
# ================================================================================================================
# Round 3, Edge Device 3: Edge Model - Loss: 0.014986998401582241, Accuracy: 0.9836498498916626, Recall: 0.9970995783805847, Precision: 0.9863072633743286
# Training Time: 150.12052536010742 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 5.12%, Average Memory Usage: 33.04 GB
# ================================================================================================================
# Round 3, Edge Device 4: Edge Model - Loss: 0.0063103376887738705, Accuracy: 0.9909678101539612, Recall: 0.9952783584594727, Precision: 0.9954715967178345
# Training Time: 152.1350691318512 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.88%, Average Memory Usage: 33.67 GB
# ================================================================================================================
# Round 3, Edge Device 5: Edge Model - Loss: 0.007404092233628035, Accuracy: 0.9899760484695435, Recall: 0.9925358295440674, Precision: 0.9971862435340881
# Training Time: 152.91157817840576 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.85%, Average Memory Usage: 34.28 GB
# ================================================================================================================
# Round 3, Fog Device 2: Fog Model - Loss: 0.18614673614501953, Accuracy: 0.9765357375144958, Recall: 0.9999977946281433, Precision: 0.976537823677063
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 3, Edge Device 1: Edge Model - Loss: 0.00701103312894702, Accuracy: 0.9903059005737305, Recall: 0.9934786558151245, Precision: 0.9965837001800537
# Training Time: 151.21243810653687 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.86%, Average Memory Usage: 35.43 GB
# ================================================================================================================
# Round 3, Edge Device 2: Edge Model - Loss: 0.006204876117408276, Accuracy: 0.9910927414894104, Recall: 0.9941125512123108, Precision: 0.9967575669288635
# Training Time: 154.83841943740845 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.80%, Average Memory Usage: 36.09 GB
# ================================================================================================================
# Round 3, Edge Device 3: Edge Model - Loss: 0.006807256489992142, Accuracy: 0.990064263343811, Recall: 0.9933919906616211, Precision: 0.9964226484298706
# Training Time: 151.76659870147705 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.81%, Average Memory Usage: 28.93 GB
# ================================================================================================================
# Round 3, Edge Device 4: Edge Model - Loss: 0.005964465439319611, Accuracy: 0.991632878780365, Recall: 0.9946733117103577, Precision: 0.9967517256736755
# Training Time: 150.24806380271912 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.86%, Average Memory Usage: 29.55 GB
# ================================================================================================================
# Round 3, Edge Device 5: Edge Model - Loss: 0.006207427009940147, Accuracy: 0.9913544058799744, Recall: 0.9938043355941772, Precision: 0.9973328709602356
# Training Time: 154.57234978675842 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.78%, Average Memory Usage: 30.16 GB
# ================================================================================================================
# Round 3, Fog Device 3: Fog Model - Loss: 0.1622011810541153, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 3, Edge Device 1: Edge Model - Loss: 0.007257417310029268, Accuracy: 0.9901652932167053, Recall: 0.9932994842529297, Precision: 0.9966182112693787
# Training Time: 148.54400777816772 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.88%, Average Memory Usage: 31.30 GB
# ================================================================================================================
# Round 3, Edge Device 2: Edge Model - Loss: 0.0063884626142680645, Accuracy: 0.9910034537315369, Recall: 0.994797945022583, Precision: 0.9959845542907715
# Training Time: 161.94932746887207 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.65%, Average Memory Usage: 31.92 GB
# ================================================================================================================
# Round 3, Edge Device 3: Edge Model - Loss: 0.006622924003750086, Accuracy: 0.9904693961143494, Recall: 0.992987334728241, Precision: 0.9972413778305054
# Training Time: 154.09247589111328 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.80%, Average Memory Usage: 32.53 GB
# ================================================================================================================
# Round 3, Edge Device 4: Edge Model - Loss: 0.005752370692789555, Accuracy: 0.9919766187667847, Recall: 0.9954724311828613, Precision: 0.9963083267211914
# Training Time: 159.14222502708435 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.68%, Average Memory Usage: 33.18 GB
# ================================================================================================================
# Round 3, Edge Device 5: Edge Model - Loss: 0.015188495628535748, Accuracy: 0.9832475185394287, Recall: 0.996812641620636, Precision: 0.986181378364563
# Training Time: 160.8568549156189 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.57%, Average Memory Usage: 33.80 GB
# ================================================================================================================
# Round 3, Fog Device 4: Fog Model - Loss: 0.1682177484035492, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 3, Edge Device 1: Edge Model - Loss: 0.006113626062870026, Accuracy: 0.9913026690483093, Recall: 0.9949577450752258, Precision: 0.996131420135498
# Training Time: 166.41817092895508 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.49%, Average Memory Usage: 34.98 GB
# ================================================================================================================
# Round 3, Edge Device 2: Edge Model - Loss: 0.005877006333321333, Accuracy: 0.9916260838508606, Recall: 0.9942898154258728, Precision: 0.9971268773078918
# Training Time: 147.51755285263062 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.93%, Average Memory Usage: 35.60 GB
# ================================================================================================================
# Round 3, Edge Device 3: Edge Model - Loss: 0.0062050651758909225, Accuracy: 0.9910727143287659, Recall: 0.9932742714881897, Precision: 0.9975734949111938
# Training Time: 154.7651515007019 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.82%, Average Memory Usage: 36.26 GB
# ================================================================================================================
# Round 3, Edge Device 4: Edge Model - Loss: 0.0061835334636271, Accuracy: 0.991202712059021, Recall: 0.9952516555786133, Precision: 0.995737612247467
# Training Time: 156.9516944885254 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.76%, Average Memory Usage: 36.89 GB
# ================================================================================================================
# Round 3, Edge Device 5: Edge Model - Loss: 0.0061496105045080185, Accuracy: 0.9912958741188049, Recall: 0.9936175346374512, Precision: 0.9974594116210938
# Training Time: 160.1996157169342 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.67%, Average Memory Usage: 29.78 GB
# ================================================================================================================
# Round 3, Fog Device 5: Fog Model - Loss: 0.15558169782161713, Accuracy: 0.9765343070030212, Recall: 0.9999963641166687, Precision: 0.9765377640724182
# Global Model Size - 0.046875 KB
# ===================================================================================================================
# Round 3: Global Model - Loss: 0.1706485003232956, Accuracy: 0.9765343070030212, Recall: 0.9999963641166687, Precision: 0.9765377640724182
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 4, Edge Device 1: Edge Model - Loss: 0.007459880318492651, Accuracy: 0.9901303052902222, Recall: 0.9929368495941162, Precision: 0.996944010257721
# Training Time: 146.051344871521 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.97%, Average Memory Usage: 31.44 GB
# ================================================================================================================
# Round 4, Edge Device 2: Edge Model - Loss: 0.005945621524006128, Accuracy: 0.9915989637374878, Recall: 0.9942613244056702, Precision: 0.9971275329589844
# Training Time: 156.61553573608398 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.73%, Average Memory Usage: 32.06 GB
# ================================================================================================================
# Round 4, Edge Device 3: Edge Model - Loss: 0.006507697515189648, Accuracy: 0.9903805255889893, Recall: 0.9925910234451294, Precision: 0.9975461959838867
# Training Time: 153.08084321022034 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.88%, Average Memory Usage: 32.70 GB
# ================================================================================================================
# Round 4, Edge Device 4: Edge Model - Loss: 0.007642035838216543, Accuracy: 0.9897915124893188, Recall: 0.9924612641334534, Precision: 0.9970714449882507
# Training Time: 165.7712161540985 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.54%, Average Memory Usage: 33.34 GB
# ================================================================================================================
# Round 4, Edge Device 5: Edge Model - Loss: 0.0070439670234918594, Accuracy: 0.9903209209442139, Recall: 0.9935616254806519, Precision: 0.9965164065361023
# Training Time: 160.82721185684204 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.66%, Average Memory Usage: 33.98 GB
# ================================================================================================================
# Round 4, Fog Device 1: Fog Model - Loss: 0.21294525265693665, Accuracy: 0.9767941832542419, Recall: 0.9998471736907959, Precision: 0.9769306182861328
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 4, Edge Device 1: Edge Model - Loss: 0.005999214947223663, Accuracy: 0.9914725422859192, Recall: 0.9938749074935913, Precision: 0.9973835945129395
# Training Time: 156.14901113510132 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.77%, Average Memory Usage: 35.10 GB
# ================================================================================================================
# Round 4, Edge Device 2: Edge Model - Loss: 0.0068008266389369965, Accuracy: 0.9908317923545837, Recall: 0.9936581254005432, Precision: 0.9969432950019836
# Training Time: 154.2121922969818 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.79%, Average Memory Usage: 35.73 GB
# ================================================================================================================
# Round 4, Edge Device 3: Edge Model - Loss: 0.0061429222114384174, Accuracy: 0.9913926124572754, Recall: 0.9934505224227905, Precision: 0.9977255463600159
# Training Time: 154.46341156959534 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.75%, Average Memory Usage: 36.37 GB
# ================================================================================================================
# Round 4, Edge Device 4: Edge Model - Loss: 0.015774177387356758, Accuracy: 0.9830765128135681, Recall: 0.9959666728973389, Precision: 0.9868252873420715
# Training Time: 149.24287509918213 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.85%, Average Memory Usage: 37.01 GB
# ================================================================================================================
# Round 4, Edge Device 5: Edge Model - Loss: 0.0077151651494205, Accuracy: 0.9891325235366821, Recall: 0.9905844330787659, Precision: 0.9982736706733704
# Training Time: 147.83767557144165 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.94%, Average Memory Usage: 37.66 GB
# ================================================================================================================
# Round 4, Fog Device 2: Fog Model - Loss: 0.32997748255729675, Accuracy: 0.023531386628746986, Recall: 8.444608829449862e-05, Precision: 0.861940324306488
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 4, Edge Device 1: Edge Model - Loss: 0.007140963803976774, Accuracy: 0.9903026819229126, Recall: 0.9928937554359436, Precision: 0.9971638321876526
# Training Time: 163.67208099365234 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.59%, Average Memory Usage: 30.40 GB
# ================================================================================================================
# Round 4, Edge Device 2: Edge Model - Loss: 0.007310916669666767, Accuracy: 0.9898664951324463, Recall: 0.9934936165809631, Precision: 0.9961191415786743
# Training Time: 160.8258204460144 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.64%, Average Memory Usage: 30.98 GB
# ================================================================================================================
# Round 4, Edge Device 3: Edge Model - Loss: 0.007141937967389822, Accuracy: 0.9893984794616699, Recall: 0.9950973987579346, Precision: 0.9940525889396667
# Training Time: 152.12803983688354 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.84%, Average Memory Usage: 31.58 GB
# ================================================================================================================
# Round 4, Edge Device 4: Edge Model - Loss: 0.006918564438819885, Accuracy: 0.9907214641571045, Recall: 0.9936760663986206, Precision: 0.9968124628067017
# Training Time: 163.78733682632446 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.56%, Average Memory Usage: 32.20 GB
# ================================================================================================================
# Round 4, Edge Device 5: Edge Model - Loss: 0.006787066347897053, Accuracy: 0.9904429912567139, Recall: 0.9928634166717529, Precision: 0.997338056564331
# Training Time: 161.43346071243286 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.63%, Average Memory Usage: 32.82 GB
# ================================================================================================================
# Round 4, Fog Device 3: Fog Model - Loss: 0.3296363055706024, Accuracy: 0.023467127233743668, Recall: 5.117944965604693e-06, Precision: 1.0
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 4, Edge Device 1: Edge Model - Loss: 0.016276922076940536, Accuracy: 0.9822579026222229, Recall: 0.9968681931495667, Precision: 0.9851403832435608
# Training Time: 151.7269880771637 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.82%, Average Memory Usage: 33.96 GB
# ================================================================================================================
# Round 4, Edge Device 2: Edge Model - Loss: 0.023462504148483276, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Training Time: 157.18931317329407 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.72%, Average Memory Usage: 34.59 GB
# ================================================================================================================
# Round 4, Edge Device 3: Edge Model - Loss: 0.006726924795657396, Accuracy: 0.9903812408447266, Recall: 0.9928838610649109, Precision: 0.9972542524337769
# Training Time: 156.5900571346283 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.77%, Average Memory Usage: 35.19 GB
# ================================================================================================================
# Round 4, Edge Device 4: Edge Model - Loss: 0.006307924631983042, Accuracy: 0.9908235669136047, Recall: 0.9942383170127869, Precision: 0.9963570237159729
# Training Time: 157.65970087051392 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.69%, Average Memory Usage: 35.82 GB
# ================================================================================================================
# Round 4, Edge Device 5: Edge Model - Loss: 0.006454536225646734, Accuracy: 0.9906068444252014, Recall: 0.9926484227180481, Precision: 0.9977211356163025
# Training Time: 157.81367444992065 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.69%, Average Memory Usage: 36.43 GB
# ================================================================================================================
# Round 4, Fog Device 4: Fog Model - Loss: 0.2103954702615738, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 4, Edge Device 1: Edge Model - Loss: 0.006459006108343601, Accuracy: 0.9906914830207825, Recall: 0.9944719076156616, Precision: 0.9959897994995117
# Training Time: 153.1522765159607 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.80%, Average Memory Usage: 37.56 GB
# ================================================================================================================
# Round 4, Edge Device 2: Edge Model - Loss: 0.006282423157244921, Accuracy: 0.9910227656364441, Recall: 0.9951836466789246, Precision: 0.9956215023994446
# Training Time: 160.5521059036255 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.68%, Average Memory Usage: 38.18 GB
# ================================================================================================================
# Round 4, Edge Device 3: Edge Model - Loss: 0.0062137688510119915, Accuracy: 0.9911116361618042, Recall: 0.9947394728660583, Precision: 0.9961531758308411
# Training Time: 158.29442954063416 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.69%, Average Memory Usage: 31.13 GB
# ================================================================================================================
# Round 4, Edge Device 4: Edge Model - Loss: 0.006041060667484999, Accuracy: 0.9913276433944702, Recall: 0.9931890964508057, Precision: 0.9979202747344971
# Training Time: 161.7217493057251 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.63%, Average Memory Usage: 31.69 GB
# ================================================================================================================
# Round 4, Edge Device 5: Edge Model - Loss: 0.00627885852009058, Accuracy: 0.991148054599762, Recall: 0.9944810271263123, Precision: 0.9964473247528076
# Training Time: 149.26586484909058 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.95%, Average Memory Usage: 32.31 GB
# ================================================================================================================
# Round 4, Fog Device 5: Fog Model - Loss: 0.15095867216587067, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ===================================================================================================================
# Round 4: Global Model - Loss: 0.33155369758605957, Accuracy: 0.023462487384676933, Recall: 3.6556750160343654e-07, Precision: 1.0
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 5, Edge Device 1: Edge Model - Loss: 0.006839125882834196, Accuracy: 0.9909813404083252, Recall: 0.9944159388542175, Precision: 0.9963416457176208
# Training Time: 148.94415760040283 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.90%, Average Memory Usage: 33.97 GB
# ================================================================================================================
# Round 5, Edge Device 2: Edge Model - Loss: 0.01605015993118286, Accuracy: 0.9824464321136475, Recall: 0.9962752461433411, Precision: 0.9858978986740112
# Training Time: 154.21408867835999 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.83%, Average Memory Usage: 34.59 GB
# ================================================================================================================
# Round 5, Edge Device 3: Edge Model - Loss: 0.006272992584854364, Accuracy: 0.9916325211524963, Recall: 0.9943201541900635, Precision: 0.997103214263916
# Training Time: 158.73729133605957 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.74%, Average Memory Usage: 35.21 GB
# ================================================================================================================
# Round 5, Edge Device 4: Edge Model - Loss: 0.006052638869732618, Accuracy: 0.9914054274559021, Recall: 0.9936073422431946, Precision: 0.9975820183753967
# Training Time: 158.9744188785553 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.66%, Average Memory Usage: 35.84 GB
# ================================================================================================================
# Round 5, Edge Device 5: Edge Model - Loss: 0.006377589423209429, Accuracy: 0.9910748600959778, Recall: 0.9946301579475403, Precision: 0.9962242245674133
# Training Time: 157.50977969169617 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.80%, Average Memory Usage: 36.46 GB
# ================================================================================================================
# Round 5, Fog Device 1: Fog Model - Loss: 0.12843888998031616, Accuracy: 0.9765357375144958, Recall: 0.9999977946281433, Precision: 0.976537823677063
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 5, Edge Device 1: Edge Model - Loss: 0.006467618513852358, Accuracy: 0.990595817565918, Recall: 0.9935137629508972, Precision: 0.9968456029891968
# Training Time: 154.8700499534607 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.79%, Average Memory Usage: 37.58 GB
# ================================================================================================================
# Round 5, Edge Device 2: Edge Model - Loss: 0.0060628866776824, Accuracy: 0.9913815259933472, Recall: 0.9942174553871155, Precision: 0.9969486594200134
# Training Time: 150.15178775787354 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.88%, Average Memory Usage: 38.18 GB
# ================================================================================================================
# Round 5, Edge Device 3: Edge Model - Loss: 0.006393612828105688, Accuracy: 0.990826427936554, Recall: 0.9943932890892029, Precision: 0.9962058067321777
# Training Time: 149.99115705490112 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.85%, Average Memory Usage: 38.83 GB
# ================================================================================================================
# Round 5, Edge Device 4: Edge Model - Loss: 0.008411447517573833, Accuracy: 0.9879015684127808, Recall: 0.9896515011787415, Precision: 0.997942328453064
# Training Time: 156.81013917922974 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.77%, Average Memory Usage: 39.49 GB
# ================================================================================================================
# Round 5, Edge Device 5: Edge Model - Loss: 0.006940597202628851, Accuracy: 0.9901691675186157, Recall: 0.9931660890579224, Precision: 0.9967552423477173
# Training Time: 158.6396780014038 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.71%, Average Memory Usage: 32.10 GB
# ================================================================================================================
# Round 5, Fog Device 2: Fog Model - Loss: 0.15193051099777222, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 5, Edge Device 1: Edge Model - Loss: 0.006504318211227655, Accuracy: 0.9906304478645325, Recall: 0.9950845837593079, Precision: 0.9953196048736572
# Training Time: 150.11304593086243 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.90%, Average Memory Usage: 33.13 GB
# ================================================================================================================
# Round 5, Edge Device 2: Edge Model - Loss: 0.00618614349514246, Accuracy: 0.9912062287330627, Recall: 0.9942935109138489, Precision: 0.9966935515403748
# Training Time: 150.07157921791077 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.94%, Average Memory Usage: 33.75 GB
# ================================================================================================================
# Round 5, Edge Device 3: Edge Model - Loss: 0.007385456468909979, Accuracy: 0.9900335669517517, Recall: 0.9926148056983948, Precision: 0.9971663355827332
# Training Time: 151.56165647506714 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.88%, Average Memory Usage: 34.37 GB
# ================================================================================================================
# Round 5, Edge Device 4: Edge Model - Loss: 0.006042111665010452, Accuracy: 0.9915300607681274, Recall: 0.9937499165534973, Precision: 0.997567355632782
# Training Time: 155.2902262210846 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.80%, Average Memory Usage: 34.98 GB
# ================================================================================================================
# Round 5, Edge Device 5: Edge Model - Loss: 0.0061423396691679955, Accuracy: 0.9913129806518555, Recall: 0.9949219226837158, Precision: 0.9961775541305542
# Training Time: 162.20045280456543 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.63%, Average Memory Usage: 35.62 GB
# ================================================================================================================
# Round 5, Fog Device 3: Fog Model - Loss: 0.13832136988639832, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 5, Edge Device 1: Edge Model - Loss: 0.006943332497030497, Accuracy: 0.9907243251800537, Recall: 0.9926334619522095, Precision: 0.9978567957878113
# Training Time: 163.88989067077637 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.57%, Average Memory Usage: 36.73 GB
# ================================================================================================================
# Round 5, Edge Device 2: Edge Model - Loss: 0.0164845772087574, Accuracy: 0.9806210994720459, Recall: 0.9982028603553772, Precision: 0.9822412729263306
# Training Time: 157.92099571228027 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.65%, Average Memory Usage: 37.35 GB
# ================================================================================================================
# Round 5, Edge Device 3: Edge Model - Loss: 0.005817191209644079, Accuracy: 0.9918306469917297, Recall: 0.9947072863578796, Precision: 0.9969202280044556
# Training Time: 154.20247626304626 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.82%, Average Memory Usage: 37.97 GB
# ================================================================================================================
# Round 5, Edge Device 4: Edge Model - Loss: 0.006287204567342997, Accuracy: 0.9910241961479187, Recall: 0.9937524795532227, Precision: 0.9970463514328003
# Training Time: 149.11063718795776 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.89%, Average Memory Usage: 38.61 GB
# ================================================================================================================
# Round 5, Edge Device 5: Edge Model - Loss: 0.0064418502151966095, Accuracy: 0.9908192753791809, Recall: 0.9932388067245483, Precision: 0.997348964214325
# Training Time: 150.80478644371033 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.82%, Average Memory Usage: 39.16 GB
# ================================================================================================================
# Round 5, Fog Device 4: Fog Model - Loss: 0.13980688154697418, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ================================================================================================================
# Round 5, Edge Device 1: Edge Model - Loss: 0.0072503117844462395, Accuracy: 0.9893041849136353, Recall: 0.9955177903175354, Precision: 0.9935423135757446
# Training Time: 159.20933556556702 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.70%, Average Memory Usage: 40.32 GB
# ================================================================================================================
# Round 5, Edge Device 3: Edge Model - Loss: 0.007527944631874561, Accuracy: 0.9895826578140259, Recall: 0.9934439063072205, Precision: 0.9958783984184265
# Training Time: 158.25476837158203 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.77%, Average Memory Usage: 33.49 GB
# ================================================================================================================
# Round 5, Edge Device 4: Edge Model - Loss: 0.006291951984167099, Accuracy: 0.9910295605659485, Recall: 0.9945687651634216, Precision: 0.9962389469146729
# Training Time: 162.50017166137695 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.59%, Average Memory Usage: 34.11 GB
# ================================================================================================================
# Round 5, Edge Device 5: Edge Model - Loss: 0.008056089282035828, Accuracy: 0.98882657289505, Recall: 0.9919289946556091, Precision: 0.9966132044792175
# Training Time: 156.2791826725006 seconds, Model Size: 0.046875 KB
# Average CPU Percent: 4.82%, Average Memory Usage: 34.72 GB
# ================================================================================================================
# Round 5, Fog Device 5: Fog Model - Loss: 0.14192339777946472, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB
# ===================================================================================================================
# Round 5: Global Model - Loss: 0.14008760452270508, Accuracy: 0.9765378832817078, Recall: 1.0, Precision: 0.9765378832817078
# Global Model Size - 0.046875 KB

# %%
centralize_learning = create_classification_model(input_shape=input_shape)

# Measure resource utilization 
# Create a threading.Event to signal the monitoring thread to stop
stop_monitoring2 = threading.Event()

# Create lists to store CPU and memory utilization values
cpu_percent_list2 = []
memory_usage_list2 = []

# Start monitoring in a separate thread
monitor_thread2 = threading.Thread(target=monitor_resources, args=(cpu_percent_list2, memory_usage_list2, stop_monitoring2))
monitor_thread2.start()

# Start time of training
start_train_cent = time.time()

# Perform training using the data
centralize_learning.fit(X_train, y_train, epochs=5, verbose=0)

# End time of training
end_train_cent = time.time()

# Signal the monitoring thread to stop
stop_monitoring2.set()

# Wait for the monitoring thread to finish
monitor_thread2.join()

# Calculte training time
train_time_cent = end_train_cent - start_train_cent

# Calculate the average CPU and memory utilization
average_cpu_percent2 = sum(cpu_percent_list2) / len(cpu_percent_list2)
average_memory_usage2 = sum(memory_usage_list2) / len(memory_usage_list2)

# Measure edge model size in bytes
current_model_size_cent_bytes = sys.getsizeof(centralize_learning)

# Convert to megabytes
current_model_size_cent_mb = current_model_size_cent_bytes / 1024  # 1 MB = 1024 KB

# Evaluate edge model on the testing set
loss_cent, accuracy_cent, recall_cent, precision_cent = centralize_learning.evaluate(X_test, y_test, verbose=0)

print('===================================================================================================================\n')
print(f"Centralize Learning - Loss: {loss_cent}, Accuracy: {accuracy_cent}, Recall: {recall_cent}, Precision: {precision_cent}\n")
print(f"Training Time: {train_time_cent} seconds \n")
print(f"Model Size: {current_model_size_cent_mb} KB\n")
print(f"Average CPU Percent: {average_cpu_percent2:.2f}%")
print(f"Average Memory Usage: {average_memory_usage2:.2f} GB")
# Out:
# ===================================================================================================================
#
# Centralize Learning - Loss: 0.004564844537526369, Accuracy: 0.9936402440071106, Recall: 0.9955503344535828, Precision: 0.9979321956634521
#
# Training Time: 4041.0752148628235 seconds
#
# Model Size: 0.046875 KB
#
# Average CPU Percent: 4.70%
# Average Memory Usage: 40.78 GB
